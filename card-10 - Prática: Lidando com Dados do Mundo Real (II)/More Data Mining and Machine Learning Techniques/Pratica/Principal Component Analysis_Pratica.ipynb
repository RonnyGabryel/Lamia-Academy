# %%
from sklearn.datasets import load_iris
from sklearn.decomposition import PCA
import pylab as pl
from itertools import cycle

# %% [markdown]
# # Activity
# Our results suggest we could actually distill this data down to a single dimension and still preserve most of its variance. Try it! Do a PCA down to one component, and measure the results.

# %%
iris = load_iris() # carrega o dataset iris
X = iris.data # carrega os dados do dataset iris

pca = PCA(n_components=1).fit(X) # aplica o PCA com 1 dimensão
X_pca = pca.transform(X) # aplica a transformação PCA nos dados

# %%
print(pca.explained_variance_ratio_) # mostra a variância explicada
print(sum(pca.explained_variance_ratio_)) # mostra o total de variância preservada
# Out:
# [0.92461872]
# 0.9246187232017339
