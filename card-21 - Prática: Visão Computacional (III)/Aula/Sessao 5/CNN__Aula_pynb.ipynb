# %%
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# tensores
x_train = torch.tensor([[[[4,5,6,7], [5,6,7,8], [8,9,10,11], [4,6,7,8]]],[[[-4,5,6,-7], [5,-6,7,8], [-8,9,-10,11], [-4,-6,-7,-8]]]]).float().to(device)
x_train.div_(8)
y_train = torch.tensor([0,1]).float().to(device) # As classes

# %%
y_train.shape
# Out:
# torch.Size([2])

# %%
x_train.shape
# Out:
# torch.Size([2, 1, 4, 4])

# %%
import torch # biblioteca do PyTorch para lidar com tensores
import torch.nn as nn # modulo das Redes
from torch.optim import Adam # importa para atualizar os pesos

def get_model():
    model = nn.Sequential( # cria uma sequência de camadas
        nn.Conv2d(in_channels=1, out_channels=1, kernel_size=3),# camada de convolução
        nn.MaxPool2d(kernel_size=2), # reduz o tamanho da imagem
        nn.ReLU(),  # função de ativação que zera valores
        nn.Flatten(), # achata os dados 2D
        nn.Linear(1, 1),# camada que liga as entradas à saída final
        nn.Sigmoid() # transforma o resultado em um valor
    ).to(device)

    loss_fn = nn.BCELoss() # define a função de perda
    optimizer = Adam(model.parameters(), lr=0.01) # define o otimizador

    return model, loss_fn, optimizer # retorna o modelo

# %%
model, criterion, optimizer = get_model()

# %%
model
# Out:
# Sequential(
#   (0): Conv2d(1, 1, kernel_size=(3, 3), stride=(1, 1))
#   (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (2): ReLU()
#   (3): Flatten(start_dim=1, end_dim=-1)
#   (4): Linear(in_features=1, out_features=1, bias=True)
#   (5): Sigmoid()
# )

# %%
# criando a função de treinamento
def train_batch(x, y, model, optimizer, loss_fn):
    model.train()
    optimizer.zero_grad()
    predictions = model(x)
    batch_loss = loss_fn(predictions.squeeze(), y.squeeze())
    batch_loss.backward()
    optimizer.step()
    return batch_loss.item()

# %%
from torch.utils.data import DataLoader, TensorDataset, Dataset # Importa as ferramentas para gerenciar e o carregamento de dados

# Cria o carregador de dados
trn_dl = DataLoader(
    TensorDataset(x_train, y_train)) # Agrupa os dados e rótulos em um lugar

# %%
# treinamento o modelo
for epoch in range(2000):
    for ix, batch in enumerate(trn_dl):
        x, y = batch
        x, y = x.to(device), y.to(device)
        loss = train_batch(x, y, model, optimizer, criterion)
        if ix % 100 == 0:
            print(f"Epoch {epoch}, Batch {ix}, Loss: {loss:.4f}")
# Out:
# Epoch 0, Batch 0, Loss: 0.4437
# Epoch 1, Batch 0, Loss: 0.4057
# Epoch 2, Batch 0, Loss: 0.3891
# Epoch 3, Batch 0, Loss: 0.3753
# Epoch 4, Batch 0, Loss: 0.3627
# Epoch 5, Batch 0, Loss: 0.3505
# Epoch 6, Batch 0, Loss: 0.3385
# Epoch 7, Batch 0, Loss: 0.3276
# Epoch 8, Batch 0, Loss: 0.3186
# Epoch 9, Batch 0, Loss: 0.3112
# Epoch 10, Batch 0, Loss: 0.3049
# Epoch 11, Batch 0, Loss: 0.2993
# Epoch 12, Batch 0, Loss: 0.2941
# Epoch 13, Batch 0, Loss: 0.2892
# Epoch 14, Batch 0, Loss: 0.2831
# Epoch 15, Batch 0, Loss: 0.2756
# Epoch 16, Batch 0, Loss: 0.2673
# Epoch 17, Batch 0, Loss: 0.2581
# Epoch 18, Batch 0, Loss: 0.2477
# Epoch 19, Batch 0, Loss: 0.2365
# Epoch 20, Batch 0, Loss: 0.2248
# Epoch 21, Batch 0, Loss: 0.2128
# Epoch 22, Batch 0, Loss: 0.2007
# Epoch 23, Batch 0, Loss: 0.1888
# Epoch 24, Batch 0, Loss: 0.1771
# Epoch 25, Batch 0, Loss: 0.1659
# Epoch 26, Batch 0, Loss: 0.1552
# Epoch 27, Batch 0, Loss: 0.1449
# Epoch 28, Batch 0, Loss: 0.1353
# ...

# %%
model(X_train[:1])
# Out:
# tensor([[3.2196e-05]], grad_fn=<SigmoidBackward0>)
