# %%
import torch # Importa a biblioteca para trabalhar com tensores

# %%
# criando um vetor simples 1D
sample = torch.tensor([1, 2, 3])
sample.shape
# Out:
# torch.Size([3])

# %%
# criando uma matriz com várias linhas 2d
x = torch.tensor([[1, 2, 3], [4, 5, 6]])
x.shape
# Out:
# torch.Size([2, 3])

# %%
# Criando uma coluna vertical
y = torch.tensor([[10], [11], [12]])
y.shape
# Out:
# torch.Size([3, 1])

# %%
import plotly.graph_objects as go # biblioteca para criar o gráfico
import plotly.offline as pyo       # biblioteca para exibir o gráfico

# Criando um Tensor 3D no caso 2 matrizes cada uma com 2 linhas e 2 colunas
a = torch.tensor([[[1, 2], [3, 4]], [[5, 6], [7, 8]]])

# listas vazias para guardar as coordenadas
x_vals = []
y_vals = []
z_vals = []

# Três laços para percorrer as 3 dimensões do tensor:
for i in range(a.shape[0]):
    for j in range(a.shape[1]):
        for k in range(a.shape[2]):
            x_vals.append(i)
            y_vals.append(j)
            z_vals.append(k)

# Configurando o gráfico 3D
trace = go.Scatter3d(
    x=x_vals, y=y_vals, z=z_vals,
    mode='markers',
    marker=dict(
        size=5,
        color=z_vals,
        colorscale='Viridis',
        opacity=0.8
    ),
)

# Configurando o visual
layout = go.Layout(
    margin=dict(l=0, r=0, b=0, t=0),
    scene=dict(
        xaxis=dict(title='Eixo X'),
        yaxis=dict(title='Eixo Y'),
        zaxis=dict(title='Eixo Z'),
    )
)

fig = go.Figure(data=[trace], layout=layout)
pyo.iplot(fig, filename='tensor.html') # Abre o gráfico no seu navegador ou notebook
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
