# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats as sp

carros = sns.load_dataset('mpg') #dataset de carros do seaborn

carros.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
# Mean, Median and Mode

carros.mean(numeric_only=True)

carros.median(numeric_only=True)

sp.mode(carros['mpg'])
# Out:
# ModeResult(mode=np.float64(13.0), count=np.int64(20))

# %%
# variation and standard deviation

carros['mpg'].var() #variation

carros['mpg'].std() #standard deviation
# Out:
# 7.815984312565782

# %%
# percentiles and moments

mpg_values = carros['mpg'].values
weight_values = carros['weight'].values

np.percentile(mpg_values, 25)

np.percentile(mpg_values, 50)

np.percentile(mpg_values, 75)

np.mean(mpg_values)

np.var(mpg_values)

sp.skew(mpg_values)

sp.kurtosis(mpg_values)
# Out:
# np.float64(-0.5194245405990441)

# %%
# visualizações

plt.figure(figsize=(8,6))
plt.hist(mpg_values, bins=20, color='skyblue', edgecolor='black', alpha=0.7)
plt.title("Histograma de MPG (Matplotlib)")
plt.xlabel("MPG")
plt.ylabel("Frequência")

plt.figure(figsize=(8,6))
sns.histplot(mpg_values, kde=True, bins=20, color='green')
plt.title("Histograma de MPG com KDE (Seaborn)")
plt.xlabel("MPG")
plt.ylabel("Frequência")
# Out:
# Text(0, 0.5, 'Frequência')

# %%
# covariance and correlation

cov = np.cov(mpg_values, weight_values)[0,1] #covariancia
cov

np.corrcoef(mpg_values, weight_values)[0,1]#correlação
# Out:
# np.float64(-0.8317409332443345)

# %%
# conditional propability

# probabilidade do mpg ser maior que 25 dado que o carro é americano
# evento a: mpg > 25
# evento b: carro é americano

carros_usa = carros[carros['origin'] == 'usa']#filtra para carros americanos
total_usa = len(carros_usa)

# %%
# Número de registros onde mpg é maior que 25 para carros americanos
num_mpg_maior_25 = len(carros_usa[carros_usa['mpg'] > 25])

# %%
# Cálculo da probabilidade condicional: P(mpg > 25 | carro é americano)
prob_condicional = num_mpg_maior_25 / total_usa if total_usa > 0 else np.nan
prob_condicional
# Out:
# 0.21686746987951808
