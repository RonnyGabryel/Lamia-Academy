# %%
import numpy as np
incomes = np.random.normal(27000, 15000, 10000)
np.mean(incomes)
# Out:
# np.float64(26910.32533654465)

# %%
import matplotlib.pyplot as plt 
plt.hist(incomes,50)
plt.show()

# %%
np.median(incomes)
# Out:
# np.float64(26872.69997133362)

# %%
incomes = np.append(incomes,[1000000000])

# %%
np.median(incomes)
# Out:
# np.float64(26873.378066596786)

# %%
np.mean(incomes)
# Out:
# np.float64(126897.63557298736)

# %%
ages = np.random.randint(18, high=90, size=500)
ages
# Out:
# array([69, 42, 30, 63, 57, 58, 71, 60, 82, 89, 74, 71, 19, 40, 65, 66, 41,
#        50, 79, 49, 39, 61, 50, 48, 88, 29, 39, 59, 64, 42, 49, 81, 75, 29,
#        86, 28, 79, 30, 65, 48, 45, 19, 37, 58, 59, 38, 82, 74, 38, 62, 79,
#        63, 24, 22, 82, 79, 31, 37, 30, 23, 72, 81, 28, 68, 23, 81, 32, 21,
#        86, 54, 71, 43, 78, 40, 62, 27, 28, 51, 53, 26, 81, 34, 68, 65, 88,
#        81, 83, 86, 57, 76, 87, 61, 18, 58, 55, 51, 34, 18, 87, 46, 41, 75,
#        67, 59, 19, 23, 34, 45, 57, 55, 74, 25, 27, 76, 71, 30, 82, 28, 78,
#        88, 69, 24, 80, 62, 36, 74, 74, 54, 69, 73, 27, 89, 72, 34, 30, 53,
#        82, 60, 42, 70, 50, 51, 28, 77, 83, 82, 48, 89, 60, 26, 23, 59, 49,
#        28, 35, 18, 70, 62, 61, 70, 64, 74, 69, 66, 52, 56, 57, 89, 53, 79,
#        56, 68, 35, 62, 73, 82, 72, 88, 24, 55, 69, 75, 67, 62, 32, 67, 89,
#        28, 60, 83, 55, 59, 47, 32, 84, 54, 87, 87, 66, 82, 43, 78, 77, 35,
#        20, 25, 40, 46, 35, 58, 32, 48, 78, 36, 88, 52, 73, 54, 34, 34, 84,
#        21, 22, 38, 21, 47, 41, 42, 64, 21, 89, 34, 71, 47, 42, 78, 89, 47,
#        25, 63, 36, 31, 45, 42, 31, 77, 77, 60, 24, 19, 69, 67, 23, 76, 45,
#        25, 80, 32, 31, 89, 47, 73, 88, 27, 62, 25, 36, 28, 28, 25, 71, 40,
#        25, 70, 68, 20, 82, 53, 86, 33, 89, 21, 73, 74, 74, 73, 82, 23, 31,
#        19, 69, 38, 70, 44, 53, 24, 74, 30, 57, 67, 63, 78, 24, 24, 40, 20,
#        70, 60, 43, 84, 56, 18, 85, 36, 26, 66, 74, 57, 71, 56, 21, 70, 71,
#        33, 87, 22, 70, 81, 46, 60, 32, 75, 36, 59, 61, 87, 46, 63, 61, 72,
#        87, 26, 73, 33, 34, 76, 35, 86, 84, 20, 38, 78, 55, 41, 71, 81, 58,
#        63, 47, 56, 48, 56, 85, 70, 40, 23, 54, 87, 50, 41, 59, 37, 64, 42,
#        37, 68, 64, 75, 75, 20, 85, 73, 67, 48, 89, 43, 65, 52, 40, 74, 35,
#        44, 66, 67, 42, 82, 69, 69, 33, 85, 80, 52, 39, 26, 37, 68, 28, 87,
#        59, 87, 27, 81, 54, 27, 77, 29, 52, 88, 75, 63, 48, 44, 88, 75, 43,
#        36, 46, 29, 69, 69, 78, 33, 78, 87, 71, 18, 54, 81, 46, 52, 80, 21,
#        42, 36, 33, 21, 21, 24, 60, 85, 53, 64, 39, 42, 80, 80, 87, 74, 38,
#        57, 48, 74, 41, 36, 56, 78, 68, 89, 73, 76, 59, 89, 41, 74, 81, 88,
#        86, 77, 49, 40, 41, 70, 48, 28, 60, 66, 80, 74, 32, 50, 56, 66, 34,
#        76, 84, 84, 55, 72, 72, 76])

# %%
from scipy import stats 
stats.mode(ages)
# Out:
# ModeResult(mode=np.int64(74), count=np.int64(15))

# %%
print("Exercicio passado na aula para:")
# Out:
# Exercicio passado na aula para:

# %%
vetor = np.random.normal(100.00, 20.00, 10000)
plt.hist(vetor, 50)
plt.show()

# %%
np.mean(vetor)
# Out:
# np.float64(99.98802411843562)

# %%
np.median(vetor)
# Out:
# np.float64(100.05257153378255)
