# %%
import pandas as pd

data = [
   ("positivo", "finalmente dropei a mount rara slk bom dms"),
    ("negativo", "wipe no primeiro boss q odio mano"),
    ("positivo", "monk ww ta mt forte no pvp"),
    ("negativo", "40 min fila arena pra nada aff"),
    ("positivo", "peguei gear top na mythic+ hj"),
    ("negativo", "tank quitou no meio da dg lixo"),
    ("positivo", "raid foi clean demais hj"),
    ("negativo", "levei gank 3x seguidas pqp"),
]

# %%
df = pd.DataFrame(data, columns=["label", "text"])
df.to_csv("wow_text.csv", index=False)
