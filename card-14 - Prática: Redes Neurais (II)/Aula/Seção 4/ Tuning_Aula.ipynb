# %% [markdown]
# # Deep Learning A Z Classificação Binária - Tuning dos parâmetros

# %%
# !pip install tensorflow==2.16.1 #instalando o tensorflow versão 2.16.1
# não preciso pois eu fiz um ambiente todo para isso

# %%
# !pip install scikeras #instalando o scikeras
#não precisa eu fiz o ambiente todo para isso

# %%
import pandas as pd #importa a biblioteca pandas
import tensorflow as tf #importa a biblioteca tensorflow
import sklearn #importa a biblioteca sklearn
import scikeras #importa a biblioteca scikeras
# Out:
# 2026-02-10 00:17:13.829429: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-10 00:17:13.919037: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-02-10 00:17:16.490735: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
pd.__version__, tf.__version__, sklearn.__version__, scikeras.__version__ #confirmando as versões
# Out:
# ('3.0.0', '2.20.0', '1.8.0', '0.13.0')

# %%
from scikeras.wrappers import KerasClassifier #importando o KerasClassifier
from tensorflow.keras import backend as K #importando o backend
from tensorflow.keras.models import Sequential #importando o Sequential
from sklearn.model_selection import GridSearchCV #importando o GridSear

# %%
#importando o arquivo de entradas
x = pd.read_csv('/home/Ront/Documentos/Card-14/Seção 4/entradas_breast.csv') 
y = pd.read_csv('/home/Ront/Documentos/Card-14/Seção 4/saidas_breast.csv')

# %%
def criar_rede(optimizer, loss, kernel_initializer, activation, neurons): #criando a função para criar a rede neural com parâmetros variáveis
    K.clear_session() #limpando a sessão do Keras
    rede_neural = Sequential([ #criando o modelo sequencial
        tf.keras.layers.InputLayer(shape=(30,)), #camada de entrada com 30 features
        tf.keras.layers.Dense(units=neurons, activation=activation, kernel_initializer=kernel_initializer), #primeira camada oculta com número variável de neurônios
        tf.keras.layers.Dropout(rate = 0.2), #dropout de 20% para evitar overfitting
        tf.keras.layers.Dense(units=neurons, activation=activation, kernel_initializer=kernel_initializer), #segunda camada oculta com número variável de neurônios
        tf.keras.layers.Dropout(rate = 0.2), #dropout de 20% para evitar overfitting
        tf.keras.layers.Dense(units=1, activation = 'sigmoid')]) #camada de saída com 1 neurônio para classificação binária
    rede_neural.compile(optimizer = optimizer, loss = loss, metrics = ['binary_accuracy']) #compilando a rede com otimizador e loss variáveis
    return rede_neural #retornando a rede criada

# %%
rede_neural = KerasClassifier(model = criar_rede)

# %%
# Parâmetros para o GridSearchCV
parametros = {
    'batch_size': [10, 30], # Tamanho dos folds
    'epochs': [50, 100], # Número da epoca
    'model__optimizer': ['adam', 'sgd'], # Otimizadores
    'model__loss': ['binary_crossentropy', 'hinge'], # Função de perda
    'model__kernel_initializer': ['random_uniform', 'normal'], # Inicialização dos pesos
    'model__activation': ['relu', 'tanh'], # Função de ativação
    'model__neurons': [16, 8] # Número de neurônios
}

# %%
parametros
# Out:
# {'batch_size': [10, 30],
#  'epochs': [50, 100],
#  'model__optimizer': ['adam', 'sgd'],
#  'model__loss': ['binary_crossentropy', 'hinge'],
#  'model__kernel_initializer': ['random_uniform', 'normal'],
#  'model__activation': ['relu', 'tanh'],
#  'model__neurons': [16, 8]}

# %%
2*2*2*2*2*2*2*10
# Out:
# 1280

# %%
grid_search = GridSearchCV(estimator = rede_neural, param_grid = parametros,
                           scoring = 'accuracy', cv = 5)

# %%
grid_search = grid_search.fit(x, y)
# Out:
# Epoch 1/50
# 2026-02-10 00:17:30.616328: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - binary_accuracy: 0.6066 - loss: 1.0051
# Epoch 2/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - binary_accuracy: 0.6593 - loss: 0.5748
# Epoch 3/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.7297 - loss: 0.5349
# Epoch 4/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.7363 - loss: 0.5020
# Epoch 5/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.7516 - loss: 0.5035
# Epoch 6/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.8374 - loss: 0.4190
# Epoch 7/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.8242 - loss: 0.4368
# Epoch 8/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.8440 - loss: 0.3860
# Epoch 9/50
# ...

# %%
print(grid_search)

# %%
melhores_parametros = grid_search.best_params_ #mostrar os melhores parâmetros
print(melhores_parametros)

# %%
melhor_precisao = grid_search.best_score_ # mostrar a melhor precisão
print(melhor_precisao)
