# %% [markdown]
# # Activity
# Try increasing the random variation in the test data, and see what effect it has on the r-squared error value.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
# Aumenta o ruído aleatório em purchaseAmount
pageSpeeds = np.random.normal(3.0, 1.0, 1000)
purchaseAmount = 100 - (pageSpeeds + np.random.normal(0, 5.0, 1000)) * 3  # aumenta o ruído

# %%
# Realiza a regressão linear
slope, intercept, r_value, p_value, std_err = stats.linregress(pageSpeeds, purchaseAmount)

# %%
# Imprime o valor de R-quadrado
r_value ** 2
# Out:
# np.float64(0.05995853250913372)

# %%
# Função de previsão
def predict(x):
    return slope * x + intercept
fitLine = predict(pageSpeeds)

# %%
# Plota o gráfico
plt.scatter(pageSpeeds, purchaseAmount)
plt.plot(pageSpeeds, fitLine, c='r')
plt.show()
